# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <h1 align=center><font size = 5><b>Data Visualization Using Seaborn library</b></font></h1>

# %% [markdown]
# > **Question :** How to determine which graph to use?

# %% [markdown]
# ![graphs.jpg](attachment:466105cf-86af-4502-8acb-3f5b741cdf80.jpg)

# %% [markdown]
# -------------
#
# ## **[Matplotlib](http://matplotlib.org/)**.
#
# Standard Python Visualization Library
# Matplotlib is a Python 2D plotting library. Matplotlib can be used in Python scripts, the Python and IPython shell, the jupyter notebook, web application servers, and four graphical user interface toolkits.

# %% [markdown]
# `Matplotlib.Pyplot`  :
# Each `pyplot` function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %% [markdown]
# > ### **Two types of plotting**
#
# Plotting using the Artist layer and plotting using the scripting layer.
#
#    * Option 1: Scripting layer (procedural method) - using `matplotlib.pyplot as 'plt'`
#
#         We can use plt i.e. `matplotlib.pyplot` and add more elements by calling different methods procedurally; for example, `plt.title(...)` to add title or `plt.xlabel(...)` to add label to the x-axis.
#
#    * Option 2: Artist layer (Object oriented method) - using an Axes instance from Matplotlib (preferred)
#
#         We can use an Axes instance of our current plot and store it in a variable (eg. ax). We can add more elements by calling methods with a little change in syntax (by adding "set_" to the previous methods).
#
#         For example, use `ax.set_title()` instead of `plt.title()` to add title, or `ax.set_xlabel()` instead of `plt.xlabel()` to add label to the x-axis.

# %% [markdown]
# > ### **Subplots** :
#
# Often times we might want to plot multiple plots within the same figure.
# To visualize multiple plots together, we can create a figure (overall canvas) and divide it into subplots, each containing a plot. With subplots, we usually work with the artist layer instead of the scripting layer.
#
# ```python
# fig = plt.figure() # create figure
#     ax = fig.add_subplot(nrows, ncols, plot_number) # create subplots
# ```
#
# Where,
#
# * `nrows` and `ncols` are used to notionally split the figure into (`nrows*ncols`) sub-axes,
# * `plot_number` is used to identify the particular subplot that this function is to create within the notional grid. plot_number starts at 1, increments across rows first and has a maximum of `nrows*ncols` as shown below.
#
# ![image.png](attachment:15035aa3-4da8-4b99-bbd0-18785c06b7d1.png)

# %% [markdown]
# -----------
#
# > ### **Matplotlib vs Seaborn**
#
# ![seabornMatplotlib.png](attachment:a54b5d2e-51d2-4f78-a09a-3953bf8ba0f9.png)

# %% [markdown]
# > ### **Plotting in pandas**
#
# pandas has a built-in implementation of Matplotlib that we can use. Plotting in pandas is as simple as appending a `.plot()` method to a series or dataframe.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# > ### **Set Style** :
#
# The style package adds support for easy-to-switch plotting "styles".

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# -------------
#
# ### The Dataset: Immigration to Canada from 1980 to 2013 <a id="2"></a>

# %% [markdown]
# Dataset Source: [International migration flows to and from selected countries - The 2015 revision](http://www.un.org/en/development/desa/population/migration/data/empirical2/migrationflows.shtml).
#
# The dataset contains annual data on the flows of international immigrants as recorded by the countries of destination. The data presents both inflows and outflows according to the place of birth, citizenship or place of previous / next residence both for foreigners and nationals. The current version presents data pertaining to 45 countries.
#
# ---

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'Canada.csv',encoding='latin-1')

df.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %%
df.set_index('Country', inplace=True)

df.columns = list(map(str, df.columns))
years = list(map(str, range(1980, 2014)))

df.head(5)
# Out:
#                       Type Continent           Region             DevName  \
# Country
# Afghanistan     Immigrants      Asia    Southern Asia  Developing regions
# Albania         Immigrants    Europe  Southern Europe   Developed regions
# Algeria         Immigrants    Africa  Northern Africa  Developing regions
# American Samoa  Immigrants   Oceania        Polynesia  Developing regions
# Andorra         Immigrants    Europe  Southern Europe   Developed regions
#
#                 1980  1981  1982  1983  1984  1985  ...  2005  2006  2007  \
# Country                                             ...
# Afghanistan       16    39    39    47    71   340  ...  3436  3009  2652
# Albania            1     0     0     0     0     0  ...  1223   856   702
# Algeria           80    67    71    69    63    44  ...  3626  4807  3623
# American Samoa     0     1     0     0     0     0  ...     0     1     0
# Andorra            0     0     0     0     0     0  ...     0     1     1
#
# ...

# %% [markdown]
# -----------
# ## **[Seaborn](https://seaborn.pydata.org/)**.

# %% [markdown]
# > **Question:** How to visualize immigration from Australia.

# %% [markdown]
# <div style="margin-top: 20px; background-color:#abc9bb; overflow:hidden;">
# <h3 align=center><font size = 5 color = '#1e4a35'><b>Line Plots</b></font></h3>
#
# A line plot is a type of plot which displays information as a series of data points called 'markers' connected by straight line segments. It is a basic type of chart common in many fields.
#     Use line plot for continuous data set. These are best suited for trend-based visualizations of data over a period of time.

# %%
df_australia = df.loc['Australia', years]
df_australia.index = df_australia.index.map(int)
df_australia = df_australia.astype(int)

fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.lineplot(x=df_australia.index, y=df_australia.values)

ax.set_title('Immigration from Austrialia')
ax.set_ylabel('Number of immigrants')
ax.set_xlabel('Years')


plt.tight_layout()
plt.show()

# %% [markdown]
# > **Question:** Let's compare the number of immigrants from India and China from 1980 to 2013.

# %%
df_IC = df.loc[['India', 'China'], years]
df_IC = df_IC.transpose()
df_IC.index = df_IC.index.map(int)
df_IC = df_IC.astype(int)
fig, ax = plt.subplots(figsize=(10, 8))
sns.lineplot(data=df_IC, ax=ax)

ax.set_title('Immigrants from China and India')
ax.set_ylabel('Number of immigrants')
ax.set_xlabel('Years')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---------
# -------
# > **Question:** What is the frequency distribution of the number of new immigrants from the various countries to Canada in 2013?

# %% [markdown]
# <div style="margin-top: 20px; background-color:#abc9bb; overflow:hidden;">
# <h3 align=center><font size = 5 color = '#1e4a35'><b>Histogram</b></font></h3>
#
# A histogram is a way of representing the frequency distribution of numeric dataset. The way it works is it partitions the x-axis into bins, assigns each data point in our dataset to a bin, and then counts the number of data points that have been assigned to each bin. So the y-axis is the frequency or the number of data points in each bin.
#
# Used to check a process change has occurred from one time period to another

# %% [markdown]
# --------
#
# **Note :**  By default, the histrogram method breaks up the dataset into 10 bins.

# %%
# np.histogram returns 2 values
count, bin_edges = np.histogram(df['2013'])

print(count) # frequency count
print(bin_edges) # bin ranges, default = 10 bins

# 178 countries contributed between 0 to 3412.9 immigrants 

fig, ax = plt.subplots(figsize=(10, 8))

sns.histplot(df['2013'], ax=ax) 

ax.set_title('Histogram of Immigration from 195 Countries in 2013') 
ax.set_ylabel('Number of Countries') 
ax.set_xlabel('Number of Immigrants')

ax.set_xticks(bin_edges)

plt.tight_layout()
plt.show()
# Out:
# [178  11   1   2   0   0   0   0   1   2]
# [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %% [markdown]
# > **Question**: What is the immigration distribution for Denmark, Norway, and Sweden for years 1980 - 2013?

# %%
temp = df.loc[['Denmark', 'Norway', 'Sweden'], years].T

count, bin_edges = np.histogram(temp, 15)

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
sns.histplot(temp, bins=15, ax=ax) 

ax.set_xticks(bin_edges)
ax.set_title('Histogram of Immigration from 195 Countries in 2013') 
ax.set_ylabel('Number of Countries') 
ax.set_xlabel('Number of Immigrants')

plt.tight_layout()
plt.show()

# %% [markdown]
# -------
# -------------
# > **Question** : Let's compare the number of Iceland immigrants to Canada from year 1980 to 2013.

# %% [markdown]
# <div style="margin-top: 20px; background-color:#abc9bb; overflow:hidden;">
# <h3 align=center><font size = 5 color = '#1e4a35'><b>Bar Plot</b></font></h3>
#
# A bar plot is a way of representing data where the length of the bars represents the magnitude/size of the feature/variable. Bar graphs usually represent numerical and categorical variables grouped in intervals.
#
# Vertical Bar Plot :
# In vertical bar graphs, the x-axis is used for labelling, and the length of bars on the y-axis corresponds to the magnitude of the variable being measured. Vertical bar graphs are particuarly useful in analyzing time series data. One disadvantage is that they lack space for text labelling at the foot of each bar.
#
# Horizontal Bar Plot:
# Sometimes it is more practical to represent the data horizontally, especially when we need more room for labelling the bars. In horizontal bar graphs, the y-axis is used for labelling, and the length of bars on the x-axis corresponds to the magnitude of the variable being measured.

# %%
df_iceland = df.loc['Iceland', years]
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(121)
sns.barplot(x=df_iceland.index, y=df_iceland.values, palette='Blues_d', ax=ax)
ax.tick_params(axis='x', rotation=90)
ax.set_xlabel('Year') 
ax.set_ylabel('Number of immigrants') 
ax.set_title('Iceland immigrants to Canada from 1980 to 2013') 

df_india = df.loc['India', years]
ax = fig.add_subplot(122)
sns.barplot(x=df_india.index, y=df_india.values, palette='rocket', ax=ax) 
ax.tick_params(axis='x', rotation=90)
ax.set_xlabel('Year') 
ax.set_ylabel('Number of immigrants') 
ax.set_title('India immigrants to Canada from 1980 to 2013') 

plt.tight_layout()
plt.show()

# %% [markdown]
# ------
# ------
#
# > **Question** Percentage of new immigrants grouped by continents for the entire time period from 1980 to 2013.

# %% [markdown]
# <div style="margin-top: 20px; background-color:#abc9bb; overflow:hidden;">
# <h3 align=center><font size = 5 color = '#1e4a35'><b>Pie chart</b></font></h3>
#
# A pie chart is a circular graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. We can create pie charts in Matplotlib by passing in the `kind=pie` keyword.
# *Note: Seaborn doesn't support pie charts.*

# %%
# group countries by continents and apply sum() function 
df_continents = df.groupby('Continent', axis=0).sum()

colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

df_continents['Total'].plot(kind='pie',
                            figsize=(15, 8),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.12) 
plt.axis('equal') 

# add legend
plt.legend(labels=df_continents.index, loc='upper right') 

plt.show()

# %% [markdown]
# --------
# -----------
#
# > **Question :** Compare the distribution of the number of new immigrants from India and China for the period 1980 - 2013.

# %% [markdown]
# <div style="margin-top: 20px; background-color:#abc9bb; overflow:hidden;">
# <h3 align=center><font size = 5 color = '#1e4a35'><b>Box Plot</b></font></h3>
#
# A box plot is a way of statistically representing the distribution of the data through five main dimensions:
#
# *Minimun*: Smallest number in the dataset.
# *First quartile*: Middle number between the minimum and the median.
# *Second quartile (Median)*: Middle number of the (sorted) dataset.
# *Third quartile*: Middle number between median and maximum.
# *Maximum*: Highest number in the dataset.

# %% [markdown]
# ![image.png](attachment:c3d670ae-ea12-4ba8-9b9f-1c94d67c4d41.png)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
sns.boxplot(data=df_IC, palette='deep', width=0.15, ax=ax) 

ax.set_title('Box plot of Immigrants from China and India 1980 - 2013')
ax.set_ylabel('Number of Immigrants') 

plt.tight_layout()
plt.show()

# %% [markdown]
# --------------
# --------
# > **Question :** Trend of total immigrantion to Canada (all countries combined) for the years 1980 - 2013.

# %% [markdown]
# <div style="margin-top: 20px; background-color:#abc9bb; overflow:hidden;">
# <h3 align=center><font size = 5 color = '#1e4a35'><b>Scatter Plot</b></font></h3>
#
# A scatter plot (2D) is a useful method of comparing variables against each other. Scatter plots look similar to line plots in that they both map independent and dependent variables on a 2D graph. While the datapoints are connected together by a line in a line plot, they are not connected in a scatter plot. The data in a scatter plot is considered to express a trend. With further analysis using tools like regression, we can mathematically calculate this relationship and use it to predict trends outside the dataset.

# %%
df_tot = pd.DataFrame(df[years].sum(axis=0))

# change the years to type int
df_tot.index = map(int, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace = True)

# rename columns
df_tot.columns = ['year', 'total']

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
sns.scatterplot(x=df_tot.year, y=df_tot.total, palette='deep', ax=ax) 

ax.set_title('Total Immigration to Canada from 1980 - 2013')
ax.set_xlabel('Year')
ax.set_ylabel('Number of Immigrants') 

plt.tight_layout()
plt.show()

# %% [markdown]
# ------
# -----
# > **Question :** Visualize all continent immigration over the years

# %% [markdown]
# <div style="margin-top: 20px; background-color:#abc9bb; overflow:hidden;">
# <h3 align=center><font size = 5 color = '#1e4a35'><b>Heatmap</b></font></h3>
# A heat map (or heatmap) is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. The variation in color may be by hue or intensity, giving obvious visual cues to the reader about how the phenomenon is clustered or varies over space.

# %%
df_heatmap = df_continents[['2007','2008','2009','2010','2011','2012','2013']]
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
sns.heatmap(data = df_heatmap, annot=True, fmt="d", ax = ax, cmap ="mako")
ax.set_title('Total Immigration to Canada from 2007 - 2013')
ax.set_xlabel('Year')
ax.set_ylabel('Continents')
# Out:
# Text(68.99999999999999, 0.5, 'Continents')

# %%
df_heatmap
# Out:
#                                    2007    2008    2009    2010    2011  \
# Continent
# Africa                            28284   29890   34534   40892   35441
# Asia                             133459  139894  141434  163845  146894
# Europe                            33495   34692   35078   33425   26778
# Latin America and the Caribbean   26011   26547   26867   28818   27856
# Northern America                   9463   10190    8995    8142    7677
# Oceania                            1693    1834    1860    1834    1548
#
#                                    2012    2013
# Continent
# Africa                            38083   38543
# Asia                             152218  155075
# Europe                            29177   28691
# Latin America and the Caribbean   27173   24950
# Northern America                   7892    8503
# Oceania                            1679    1775

# %% [markdown]
# -------
# ------
#
# By,
# **GAGANA HG**
